# %%
#Load packages

import numpy as np 
import matplotlib.pyplot as plt 
from sklearn.svm import SVR

# %%
#Generate 50 data points from this function in the range [– 3, 3]

X = np.linspace(-3, 3, 50) 
Y = np.sinc(datapoints) 
  
#Visualize the data points
    
plt.plot(X, Y, marker = "o") 
plt.title("Graph of sinc function") 
plt.show()

# %%
# Add Gaussian noise to the data.

noise = np.random.normal(0,0.5,50)
Y_noise = Y + noise

#Visualize the data points with noise

plt.plot(X, Y_noise, marker = "o" ) 
plt.title("Graph of sinc function with gaussian noise") 
plt.show()

# %%
#train the regressor with generated data without noise

from sklearn.svm import SVR

regressor = SVR(kernel="rbf", C=100,  epsilon=0.1, gamma="auto", degree=3, coef0=1)

regressor.fit(X.reshape(-1,1), Y.reshape(-1,1))

#Run prediction without noise using the regressor

Y_pred = regressor.predict(X.reshape(-1,1))
# Out:
# C:\Users\Rajkumar.Krishnan\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
#Plot prediction without noise

plt.plot(X, Y_pred ) 
plt.plot(X, Y, marker = "o")
plt.title("Plot of SVM regressor without noise") 
plt.show()

# %%
#train the regressor with generated data with noise

from sklearn.svm import SVR

regressor = SVR(kernel="rbf", C=100,  epsilon=0.1, gamma="auto", degree=3, coef0=1)

regressor.fit(X.reshape(-1,1), Y_noise.reshape(-1,1))

#Run prediction with noise using the regressor

Y_pred = regressor.predict(X.reshape(-1,1))
# Out:
# C:\Users\Rajkumar.Krishnan\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
#Plot prediction without noise

plt.plot(X, Y_pred ) 
plt.plot(X, Y_noise, marker = "o" ) 
plt.title("Plot of SVM regressor with noise") 
plt.show()
